# %% [markdown]
# # Astroplan Plotting Examples - Airmass vs Time

# %% [markdown]
# To generate airmass vs. time plots with `Astroplan`, use the `plot_airmass` function.
#
# This function takes, at minimum, a `Target`, an `Observer` and a `Time` object as input.
# Optional arguments include an `Axes` object and a style dictionary.
#
# `plot_airmass` will return an `Axes` object that contains airmass data for the window of time specified by the `Time` object passed in.  You can further manipulate the returned `Axes` object, or simply print the plot to your display or save it as a file.

# %% [markdown]
# ## Passing in a Time object with just one time.

# %% [markdown]
# Any plot function in `Astroplan` with a time-based axis will allow you to pass in a scalar `Time` object (e.g., `Time('2000-1-1')`, as opposed to `Time(['2000-1-1'])`).  If you do this, the plotting function will use a 24-hour window of time centered on the `Time` you passed in.  Airmass will be calculated at regular intervals throughout this period.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import astropy.units as u
from astropy.coordinates import EarthLocation, SkyCoord
from pytz import timezone
from astropy.time import Time

from astroplan import Observer
from astroplan import FixedTarget
from astroplan.plots import plot_airmass

# Set up Observer, Target and observation time objects. 
longitude = '-155d28m48.900s'
latitude = '+19d49m42.600s'
elevation = 4163 * u.m
location = EarthLocation.from_geodetic(longitude, latitude, elevation)

observer = Observer(name='Subaru Telescope',
               location=location,
               pressure=0.615 * u.bar,
               relative_humidity=0.11,
               temperature=0 * u.deg_C,
               timezone=timezone('US/Hawaii'),
               description="Subaru Telescope on Mauna Kea, Hawaii")

coordinates = SkyCoord('02h31m49.09s', '+89d15m50.8s', frame='icrs')
target = FixedTarget(name='Polaris', coord=coordinates)

observe_time = Time('2015-01-15 23:30:00')

plot_airmass(target, observer, observe_time)
plt.show()

# %% [markdown]
# ## Passing in a Time object with multiple times.

# %% [markdown]
# If you want create a `Time` object centered on a particular instant in time (such as the example above), but you want to control how many airmass calculations are used, you use a non-scalar `Time` object.  For example, using `Time(['2000-1-1 20:00:00', '2000-1-1 20:00:00'])` will give you a plot based off two calculations of parallactic angle.
#
# To quickly create a `Time` object with many instances in time, you can use `numpy.linspace()` in conjunction with `astropy.units`.

# %%
import numpy as np

observe_time = Time('2015-01-15 23:30:00')
observe_time = observe_time + np.linspace(-5, 5, 55)*u.hour

plot_airmass(target, observer, observe_time)
plt.show()

# %% [markdown]
# If you know the start and end times of your observation run, you can use a `DeltaTime` object to populate the `Time` object.

# %%
start_time = Time('2015-01-15 23:00:00')
end_time = Time('2015-01-16 04:00:00')
delta_t = end_time - start_time
observe_time = start_time + delta_t*np.linspace(0, 1, 75)

plot_airmass(target, observer, observe_time)
plt.show()

# %% [markdown]
# ## Plotting airmass for multiple targets.

# %% [markdown]
# You may want to plot airmass information for multiple targets.
#
# In this case, you simply reissue the `plot_airmass` command, using a different `Target` object as input this time.  Repeat until you have as many targets on the plot as you wish and save to a file if you like.  When you're ready to make a different plot, use `ax.cla()` to clear the `Axes` object.

# %%
coordinates = SkyCoord('06h45m08.9173s', '-16d42m58.017s', frame='icrs')
other_target = FixedTarget(name='Sirius', coord=coordinates)

coordinates = SkyCoord('07h45m19.4s', '+28d01m35s', frame='icrs')
third_target = FixedTarget(name='Pollux', coord=coordinates)

observe_time = Time('2015-01-15 23:30:00') + np.linspace(-4.5, 3.5, 25)*u.hour

sirius_styles = {'linestyle': '--', 'color': 'r'}
pollux_styles = {'linestyle': '-', 'color': 'g'}

plot_airmass(target, observer, observe_time)
plot_airmass(other_target, observer, observe_time, style_kwargs=sirius_styles)
plot_airmass(third_target, observer, observe_time, style_kwargs=pollux_styles)

plt.show()

# %% [markdown]
# ## Changing style options.

# %% [markdown]
# You can change the `linestyle` and `color` properties of individual airmasses by setting the `style_kwargs` option. See [Plotting airmass for multiple targets](http://localhost:8888/notebooks/examples/plotting_examples--airmass.ipynb#Plotting-airmass-for-multiple-targets.) above.

# %% [markdown]
# You can also set a dark background with the `dark_plot` option.

# %%
#plot_airmass(target, observer, observe_time, dark_plot=True)

#plt.show()
